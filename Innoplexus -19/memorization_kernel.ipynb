# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers.normalization import BatchNormalization
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, LearningRateScheduler
from keras.models import load_model
from keras.initializers import glorot_normal, Zeros, Ones
import keras.backend as K
from keras.optimizers import RMSprop
import tensorflow as tf

# %%
# %%time
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import os
import matplotlib.pyplot as plt
import pandas as pd
import random

from sklearn import preprocessing
import lightgbm as lgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder

from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.decomposition import PCA
from math import sqrt
from scipy import stats
from scipy.stats import norm, skew #for some statistics
# Out:
# Wall time: 453 ms

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import anago
# Out:
# Using TensorFlow backend.

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Elmo with tensorflow hub.ipynb',
#  'innoplexus_NN.ipynb',
#  'kernel56398426dd.ipynb',
#  'memorization_kernel.ipynb',
#  'sample_submission.csv',
#  'sample_submission_usrypCc.zip',
#  'submission.csv',
#  'submission.zip',
#  'submission_lgb.csv',
#  'submission_lgb.zip',
#  'submission_lgb1.csv',
#  'submission_lgb1.zip',
#  'test.csv',
#  'test_XEV14AD.zip',
#  'train.csv',
#  'train_3PIRKSI.zip',
#  'Untitled3.ipynb']

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
subm = pd.read_csv('sample_submission.csv')

# %%
train = train.fillna(method="ffill")
test = test.fillna(method="ffill")

# %%
train['Word'] = train['Word'].apply(lambda x:x.lower())
test['Word'] = test['Word'].apply(lambda x:x.lower())

# %%
test.head(5)
# Out:
#         id  Doc_ID  Sent_ID    Word
# 0  4543834   30001   191283   cccva
# 1  4543835   30001   191283       ,
# 2  4543836   30001   191283  manova
# 3  4543837   30001   191283       ,
# 4  4543838   30001   191283      my

# %%
words = list(set(train["Word"].values))
n_words = len(words); n_words
# Out:
# 158163

# %%
tags = list(set(train["tag"].values))

# %%
n_tags = len(tags); n_tags
# Out:
# 3

# %%
class SentenceGetter(object):
    
    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        self.empty = False
    
    def get_next(self):
        try:
            s = self.data[self.data["Sent_ID"] == self.n_sent]
            self.n_sent += 1
            return s["Word"].values.tolist(), s["tag"].values.tolist()    
        except:
            self.empty = True
            return None, None

# %%
class TestSentenceGetter(object):
    def __init__(self, data):
        self.n_sent = 191283
        self.data = data
        self.empty = False
    
    def get_next(self):
        try:
            s = self.data[self.data["Sent_ID"] == self.n_sent]
            self.n_sent += 1
            return s["Word"].values.tolist()   
        except:
            self.empty = True
            return None

# %%
getter = SentenceGetter(train)

# %%
getter.sentences
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-7cc19e93dac7> in <module>
# ----> 1 getter.sentences
#
# AttributeError: 'SentenceGetter' object has no attribute 'sentences'

# %%
testgetter = TestSentenceGetter(test)
testgetter.get_next()
# Out:
# ['cccva', ',', 'manova', ',', 'my', 'black', 'hen', '.']

# %%
sent, tag = getter.get_next()

# %%
print(sent)
print(tag)
# Out:
# ['Obesity', 'in', 'Low-', 'and', 'Middle-Income', 'Countries', ':', 'Burden', ',', 'Drivers', ',', 'and', 'Emerging', 'Challenges', '.']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']

# %% [markdown]
# Memorization

# %%
from sklearn.base import BaseEstimator, TransformerMixin


class MemoryTagger(BaseEstimator, TransformerMixin):
    
    def fit(self, X, y):
        '''
        Expects a list of words as X and a list of tags as y.
        '''
        voc = {}
        self.tags = []
        for x, t in zip(X, y):
            if t not in self.tags:
                self.tags.append(t)
            if x in voc:
                if t in voc[x]:
                    voc[x][t] += 1
                else:
                    voc[x][t] = 1
            else:
                voc[x] = {t: 1}
        self.memory = {}
        for k, d in voc.items():
            self.memory[k] = max(d, key=d.get)
    
    def predict(self, X, y=None):
        '''
        Predict the the tag from memory. If word is unknown, predict 'O'.
        '''
        return [self.memory.get(x, 'O') for x in X]

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import classification_report

words = train["Word"].values.tolist()
tags = train["tag"].values.tolist()

pred = cross_val_predict(estimator=MemoryTagger(), X=words, y=tags, cv=5)

# %%
report = classification_report(y_pred=pred, y_true=tags)
print(report)
# Out:
#                precision    recall  f1-score   support
#
# B-indications       0.72      0.40      0.52     53003
# I-indications       0.59      0.37      0.46     44624
#             O       0.99      1.00      0.99   4446206
#
#     micro avg       0.98      0.98      0.98   4543833
#     macro avg       0.77      0.59      0.66   4543833
#  weighted avg       0.98      0.98      0.98   4543833

# %%
tagger = MemoryTagger()

# %%
tagger.fit(words, tags)

# %%
# print(tagger.predict(testgetter.get_next()))

# %%
testwords = test["Word"].values.tolist()

# %%
pred = tagger.predict(testwords)

# %%
set(pred)
# Out:
# {'B-indications', 'I-indications', 'O'}

# %%
len(pred)
set(pred)
test.shape
# Out:
# 2994463
# {'B-indications', 'I-indications', 'O'}
# (2994463, 4)

# %%
set(subm['tag'])
# Out:
# {'O'}

# %%
subm['tag']=pred
subm.to_csv('submission.csv',index=False)

# %%
set(subm['tag'])
subm.head()
# Out:
# {'B-indications', 'I-indications', 'O'}
#         id  Sent_ID tag
# 0  4543834   191283   O
# 1  4543835   191283   O
# 2  4543836   191283   O
# 3  4543837   191283   O
# 4  4543838   191283   O

# %% [markdown]
# machine learning approach

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
def feature_map(word):
    '''Simple feature map.'''
    return np.array([ word.islower(), word.isupper(), len(word),
                     word.isdigit(),  word.isalpha()])

# %%
words = [feature_map(str(w)) for w in train["Word"].values.tolist()]

# %%
words
# Out:
# [array([0, 0, 7, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([0, 0, 4, 0, 0]),
#  array([1, 0, 3, 0, 1]),
#  array([ 0,  0, 13,  0,  0]),
#  array([0, 0, 9, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 6, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 7, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 3, 0, 1]),
#  array([0, 0, 8, 0, 1]),
#  array([ 0,  0, 10,  0,  1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 2, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([ 1,  0, 11,  0,  1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([ 1,  0, 10,  0,  1]),
#  array([1, 0, 3, 0, 1]),
#  array([ 1,  0, 10,  0,  1]),
#  array([1, 0, 7, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([ 1,  0, 15,  0,  1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 4, 0, 0]),
#  array([1, 0, 3, 0, 1]),
#  array([ 1,  0, 13,  0,  0]),
#  array([1, 0, 9, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 5, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 7, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([ 1,  0, 10,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 2, 0, 1]),
#  array([0, 0, 5, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([ 1,  0, 10,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([ 1,  0, 11,  0,  1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 7, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 3, 0, 1]),
#  array([ 1,  0, 11,  0,  0]),
#  array([ 1,  0, 10,  0,  1]),
#  array([ 1,  0, 12,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([ 0,  0, 10,  0,  1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([ 1,  0, 10,  0,  1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([ 1,  0, 11,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([0, 0, 5, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([ 1,  0, 10,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 7, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([ 1,  0, 12,  0,  1]),
#  array([1, 0, 7, 0, 1]),
#  array([ 1,  0, 12,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 8, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([ 1,  0, 13,  0,  1]),
#  array([ 1,  0, 12,  0,  1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 7, 0, 1]),
#  array([ 1,  0, 12,  0,  1]),
#  array([1, 0, 6, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([ 1,  0, 14,  0,  1]),
#  array([ 1,  0, 13,  0,  1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 3, 0, 1]),
#  array([ 1,  0, 18,  0,  0]),
#  array([ 1,  0, 10,  0,  1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 4, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([ 1,  0, 10,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([0, 0, 5, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 9, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 1, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([ 1,  0, 13,  0,  1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([ 1,  0, 10,  0,  1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([ 1,  0, 13,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([ 1,  0, 11,  0,  0]),
#  array([1, 0, 9, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([ 0,  1, 13,  0,  1]),
#  array([0, 1, 4, 0, 1]),
#  array([0, 0, 9, 0, 1]),
#  array([ 1,  0, 15,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([ 1,  0, 13,  0,  1]),
#  array([ 1,  0, 10,  0,  1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 2, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 9, 0, 0]),
#  array([ 1,  0, 15,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([ 1,  0, 14,  0,  0]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 4, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([ 1,  0, 12,  0,  0]),
#  array([1, 0, 5, 0, 1]),
#  array([0, 0, 7, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 3, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 4, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([ 1,  0, 15,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 3, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([0, 1, 3, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 5, 0, 1]),
#  array([0, 0, 7, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 3, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 3, 0, 1]),
#  array([0, 1, 4, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 2, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([ 1,  0, 10,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([0, 1, 3, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([0, 1, 4, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([ 1,  0, 10,  0,  1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 4, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([0, 1, 4, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([0, 1, 3, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([0, 1, 3, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 3, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 3, 0, 1]),
#  array([0, 1, 3, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 3, 0, 1]),
#  array([0, 1, 4, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([ 1,  0, 10,  0,  1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 1, 0, 1]),
#  array([1, 0, 4, 0, 0]),
#  array([1, 0, 8, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 4, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([ 1,  0, 11,  0,  1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 3, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 1, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([ 0,  0, 15,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([ 1,  0, 12,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 2, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 2, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 3, 0, 1]),
#  array([ 1,  0, 11,  0,  0]),
#  array([ 1,  0, 11,  0,  1]),
#  array([ 1,  0, 12,  0,  1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 3, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([ 0,  0, 12,  0,  0]),
#  array([1, 0, 7, 0, 1]),
#  array([ 1,  0, 12,  0,  1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 3, 0, 1]),
#  array([ 1,  0, 15,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([0, 1, 4, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([0, 1, 3, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([0, 1, 4, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([0, 1, 3, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 4, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 8, 0, 0]),
#  array([1, 0, 3, 0, 1]),
#  array([0, 1, 5, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 8, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([ 1,  0, 12,  0,  1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 9, 0, 0]),
#  array([ 1,  0, 15,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([0, 1, 3, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([0, 1, 4, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([0, 1, 3, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([0, 1, 3, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 5, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 8, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 5, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 8, 0, 0]),
#  array([1, 0, 3, 0, 1]),
#  array([0, 1, 5, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 8, 0, 0]),
#  array([ 1,  0, 12,  0,  1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 7, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([ 1,  0, 11,  0,  1]),
#  array([ 1,  0, 11,  0,  1]),
#  array([1, 0, 7, 0, 1]),
#  array([ 1,  0, 12,  0,  1]),
#  array([0, 1, 3, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([0, 1, 4, 0, 1]),
#  array([ 1,  0, 12,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([0, 1, 4, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([0, 1, 3, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 6, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 7, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 3, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([0, 1, 4, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 9, 0, 0]),
#  array([ 1,  0, 15,  0,  1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([0, 1, 4, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([0, 1, 3, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 8, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([ 1,  0, 11,  0,  1]),
#  array([ 1,  0, 11,  0,  1]),
#  array([1, 0, 7, 0, 1]),
#  array([0, 1, 4, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([ 1,  0, 12,  0,  0]),
#  array([0, 1, 3, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([0, 1, 4, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 7, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([0, 1, 4, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 8, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([ 1,  0, 14,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([ 1,  0, 11,  0,  1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 3, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([0, 0, 6, 0, 0]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 1, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([ 0,  0, 10,  0,  0]),
#  array([ 1,  0, 13,  0,  1]),
#  array([1, 0, 7, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([ 0,  0, 17,  0,  0]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 4, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 1, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([0, 0, 2, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 7, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([ 1,  0, 20,  0,  1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 3, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([0, 1, 5, 0, 0]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 1, 0, 1]),
#  array([ 1,  0, 14,  0,  0]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([ 0,  0, 10,  0,  0]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([0, 0, 3, 1, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 7, 0, 1]),
#  array([ 1,  0, 14,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([ 1,  0, 13,  0,  1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 7, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([ 1,  0, 12,  0,  1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 1, 0, 1]),
#  array([ 0,  0, 10,  0,  0]),
#  array([ 1,  0, 13,  0,  0]),
#  array([ 1,  0, 11,  0,  1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([ 1,  0, 13,  0,  1]),
#  array([1, 0, 4, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 2, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([0, 0, 6, 0, 0]),
#  array([1, 0, 3, 0, 1]),
#  array([ 1,  0, 12,  0,  1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([ 1,  0, 12,  0,  1]),
#  array([0, 0, 1, 0, 0]),
#  array([ 1,  0, 10,  0,  1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 4, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([ 1,  0, 13,  0,  1]),
#  array([1, 0, 3, 0, 1]),
#  array([ 1,  0, 15,  0,  1]),
#  array([0, 1, 1, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 1, 0, 1]),
#  array([0, 0, 7, 0, 0]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([ 1,  0, 11,  0,  1]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 1, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([ 1,  0, 12,  0,  1]),
#  array([0, 0, 7, 0, 0]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([0, 0, 2, 1, 0]),
#  array([1, 0, 1, 0, 1]),
#  array([ 1,  0, 17,  0,  0]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 2, 0, 1]),
#  array([0, 0, 2, 1, 0]),
#  array([1, 0, 1, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 7, 0, 0]),
#  array([ 0,  0, 10,  0,  0]),
#  array([1, 0, 3, 0, 1]),
#  array([0, 0, 6, 0, 0]),
#  array([ 0,  0, 10,  0,  0]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([ 1,  0, 11,  0,  1]),
#  array([1, 0, 9, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([ 0,  0, 12,  0,  1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 7, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 3, 0, 1]),
#  array([0, 0, 7, 0, 0]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([ 1,  0, 13,  0,  1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([0, 0, 6, 0, 0]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 3, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([0, 1, 4, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 6, 0, 0]),
#  array([1, 0, 3, 0, 1]),
#  array([0, 0, 6, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 4, 0, 1]),
#  array([ 1,  0, 12,  0,  1]),
#  array([ 1,  0, 12,  0,  1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([ 0,  0, 10,  0,  0]),
#  array([1, 0, 7, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 8, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([0, 0, 6, 0, 0]),
#  array([ 0,  0, 10,  0,  0]),
#  array([ 1,  0, 11,  0,  1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 1, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([ 1,  0, 11,  0,  1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([ 1,  0, 10,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 8, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 5, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([0, 0, 6, 0, 0]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([ 1,  0, 13,  0,  1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 1, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([ 1,  0, 13,  0,  1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 1, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([ 1,  0, 11,  0,  1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 1, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([ 0,  0, 14,  0,  0]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 4, 0, 1]),
#  array([0, 0, 1, 1, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 2, 0, 1]),
#  array([1, 0, 8, 0, 0]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([ 1,  0, 14,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([ 1,  0, 22,  0,  0]),
#  array([ 1,  0, 11,  0,  1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 1, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([ 1,  0, 10,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([ 1,  0, 11,  0,  1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 3, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([ 1,  0, 22,  0,  0]),
#  array([ 1,  0, 11,  0,  1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 4, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 3, 0, 1]),
#  array([ 1,  0, 11,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 3, 0, 1]),
#  array([ 1,  0, 14,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([0, 1, 4, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([1, 0, 1, 0, 1]),
#  array([0, 0, 8, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([ 0,  0, 14,  0,  1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([0, 1, 4, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 1, 0, 1]),
#  array([ 1,  0, 16,  0,  0]),
#  array([1, 0, 8, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([ 0,  1, 11,  0,  0]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 3, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 7, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 3, 0, 1]),
#  array([ 1,  0, 14,  0,  1]),
#  array([1, 0, 5, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([ 1,  0, 12,  0,  1]),
#  array([1, 0, 8, 0, 1]),
#  array([ 1,  0, 11,  0,  1]),
#  array([1, 0, 6, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 5, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([0, 0, 4, 0, 0]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([0, 0, 5, 0, 0]),
#  array([0, 0, 2, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 4, 0, 1]),
#  array([ 1,  0, 10,  0,  1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([ 1,  0, 12,  0,  1]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 8, 0, 1]),
#  array([0, 1, 4, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 0, 3, 0, 1]),
#  array([ 1,  0, 12,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([ 1,  0, 14,  0,  1]),
#  array([1, 0, 3, 0, 1]),
#  array([0, 0, 3, 0, 0]),
#  array([1, 0, 5, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([0, 0, 3, 0, 1]),
#  array([1, 0, 2, 0, 0]),
#  array([ 1,  0, 12,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([1, 0, 9, 0, 1]),
#  array([0, 1, 3, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 3, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 4, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 5, 0, 0]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 6, 0, 0]),
#  array([1, 0, 8, 0, 1]),
#  array([1, 0, 7, 0, 1]),
#  array([1, 0, 2, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([ 1,  0, 10,  0,  1]),
#  array([ 1,  0, 12,  0,  1]),
#  array([1, 0, 3, 0, 1]),
#  array([ 1,  0, 14,  0,  1]),
#  array([1, 0, 2, 0, 1]),
#  array([0, 1, 4, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([0, 1, 4, 0, 1]),
#  array([1, 0, 6, 0, 1]),
#  array([ 1,  0, 11,  0,  1]),
#  array([1, 0, 4, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  array([ 1,  0, 11,  0,  1]),
#  array([ 1,  0, 10,  0,  1]),
#  array([1, 0, 6, 0, 1]),
#  array([0, 0, 1, 0, 0]),
#  array([1, 0, 9, 0, 1]),
#  array([1, 0, 5, 0, 1]),
#  array([1, 0, 3, 0, 1]),
#  ...]

# %%
pred = cross_val_predict(RandomForestClassifier(n_estimators=20),
                         X=words, y=tags, cv=5)

# %%
report = classification_report(y_pred=pred, y_true=tags)
print(report)
# Out:
#                precision    recall  f1-score   support
#
# B-indications       0.00      0.00      0.00     53003
# I-indications       0.00      0.00      0.00     44624
#             O       0.98      1.00      0.99   4446206
#
#     micro avg       0.98      0.98      0.98   4543833
#     macro avg       0.33      0.33      0.33   4543833
#  weighted avg       0.96      0.98      0.97   4543833

# %%
from sklearn.preprocessing import LabelEncoder

class FeatureTransformer(BaseEstimator, TransformerMixin):
    
    def __init__(self):
        self.memory_tagger = MemoryTagger()
        self.tag_encoder = LabelEncoder()
        
    def fit(self, X):
        words = X["Word"].values.tolist()
        tags = X["tag"].values.tolist()
        self.memory_tagger.fit(words, tags)
        self.tag_encoder.fit(tags)
        return self
    
    def transform(self, X, y=None):
        words = X["Word"].values.tolist()
        out = []
        for i in range(len(words)):
            w = str(words[i])
            if i < len(words) - 1:
                wp = self.tag_encoder.transform(self.memory_tagger.predict([words[i+1]]))[0]
            else:
                wp = self.tag_encoder.transform(['O'])[0]
            if i > 0:
                if words[i-1] != ".":
                    wm = self.tag_encoder.transform(self.memory_tagger.predict([words[i-1]]))[0]
                else:
                    wm = self.tag_encoder.transform(['O'])[0]
            else:
                wm = self.tag_encoder.transform(['O'])[0]
            out.append(np.array([w.istitle(), w.islower(), w.isupper(), len(w), w.isdigit(), w.isalpha(),
                                 self.tag_encoder.transform(self.memory_tagger.predict([w]))[0], wp, wm]))
        return out

# %%
from sklearn.pipeline import Pipeline

# %%
pred = cross_val_predict(Pipeline([("feature_map", FeatureTransformer()), 
                                   ("clf", RandomForestClassifier(n_estimators=20, n_jobs=3))]),
                         X=train, y=tags, cv=3)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-d7bca0e2cae5> in <module>
#       1 pred = cross_val_predict(Pipeline([("feature_map", FeatureTransformer()),
#       2                                    ("clf", RandomForestClassifier(n_estimators=20, n_jobs=3))]),
# ----> 3                          X=train, y=tags, cv=3)
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_predict(estimator, X, y, groups, cv, n_jobs, verbose, fit_params, pre_dispatch, method)
#     775     prediction_blocks = parallel(delayed(_fit_and_predict)(
#     776         clone(estimator), X, y, train, test, verbose, fit_params, method)
# --> 777         for train, test in cv.split(X, y, groups))
#     778
#     779     # Concatenate the predictions
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self, iterable)
#     915             # remaining jobs.
#     916             self._iterating = False
# --> 917             if self.dispatch_one_batch(iterator):
#     918                 self._iterating = self._original_iterator is not None
#     919
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\externals\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\externals\joblib\parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\externals\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\externals\joblib\_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\externals\joblib\parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_predict(estimator, X, y, train, test, verbose, fit_params, method)
#     848         estimator.fit(X_train, **fit_params)
#     849     else:
# --> 850         estimator.fit(X_train, y_train, **fit_params)
#     851     func = getattr(estimator, method)
#     852     predictions = func(X_test)
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     265         Xt, fit_params = self._fit(X, y, **fit_params)
#     266         if self._final_estimator is not None:
# --> 267             self._final_estimator.fit(Xt, y, **fit_params)
#     268         return self
#     269
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     331                     t, self, X, y, sample_weight, i, len(trees),
#     332                     verbose=self.verbose, class_weight=self.class_weight)
# --> 333                 for i, t in enumerate(trees))
#     334
#     335             # Collect newly grown trees
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self, iterable)
#     928
#     929             with self._backend.retrieval_context():
# --> 930                 self.retrieve()
#     931             # Make sure that we get a last message telling us we are done
#     932             elapsed_time = time.time() - self._start_time
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\externals\joblib\parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\externals\joblib\_parallel_backends.py in wrap_future_result(future, timeout)
#     519         AsyncResults.get from multiprocessing."""
#     520         try:
# --> 521             return future.result(timeout=timeout)
#     522         except LokyTimeoutError:
#     523             raise TimeoutError()
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\concurrent\futures\_base.py in result(self, timeout)
#     425                 return self.__get_result()
#     426
# --> 427             self._condition.wait(timeout)
#     428
#     429             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
'ss'

# %%
clf = lgb.LGBMClassifier()
mod = clf.fit(words, tags)

# %%
testwords = [feature_map(str(w)) for w in test["Word"].values.tolist()]

# %%
# testwords = [FeatureTransformer().transform(w) for w in test["Word"].values.tolist()]
aa = FeatureTransformer().fit(train)
testw = aa.transform(test)

# %%
# testwords

# %%
pred = mod.predict(testwords)

# %%
set(pred)
# Out:
# {'O'}

# %%
subm['tag']=pred
subm.to_csv('submission_lgb.csv',index=False)

# %%
### Tfidf with lightgbm

# %%
from sklearn.metrics import accuracy_score
from sklearn.feature_extraction.text import TfidfVectorizer
# Transform each text into a vector of word counts
vectorizer = TfidfVectorizer(stop_words="english",ngram_range=(1, 2))
training_features = vectorizer.fit_transform(train["Word"])    
test_features = vectorizer.transform(test["Word"])

# %%
from sklearn import preprocessing 
le = preprocessing.LabelEncoder()
aa = le.fit_transform(train['tag'])

# %%
model = lgb.LGBMClassifier()
model.fit(training_features, aa)
y_pred = model.predict(test_features)
print(set(y_pred))
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# {0, 1, 2}

# %%
subm['tag']=le.inverse_transform(y_pred)
subm.to_csv('submission_lgb1.csv',index=False)

# %%
subm.head()
# Out:
#         id  Sent_ID tag
# 0  4543834   191283   O
# 1  4543835   191283   O
# 2  4543836   191283   O
# 3  4543837   191283   O
# 4  4543838   191283   O
